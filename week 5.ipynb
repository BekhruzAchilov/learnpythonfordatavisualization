# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [0.5, 2, 3, 4]
y = [2, 4, 6, 8]

plt.figure(figsize=(7,4),dpi = 300)

plt.plot(x,y, 'b^--', label = '2x')

x2 = np.arange(0,4.5, 0.5)
plt.plot(x2[:6], x2[:6]**2,'r', label = 'X^2')
plt.plot(x2[5:], x2[5:]**2,'r--')

plt.title("My first silly chart", fontdict = {"fontname": "Verdana", "fontsize": 16 })
plt.xlabel("x values")
plt.ylabel("y values")

plt.xticks([0,1,2,3,4,])
plt.yticks([0,2,4,6,7,])

plt.legend()

plt.savefig('mysillygraph.png', dpi = 300 )

plt.show()

# %%
fig, ax = plt.subplots()
# Create a figure containing a single axes.

ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  
# Plot some data on the axes.

# %%
plt.figure(figsize=(7,4),dpi = 300)
plt.title("Average household expenditure", fontdict = {"fontname": "Verdana", "fontsize": 16, })
x = [1,3,4.5,5.5]
y = [2,3,3.5,4]
plt.plot (x,y, 'b--')

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i / 50))  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=20, blit=True, save_count=50)

# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.3, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals

t = np.arange(0., 4., 0.2)

# red dashes, blue squares and green triangles
plt.title("exercise", fontdict = {"fontname": "Verdana", "fontsize": 16 })
plt.plot(t, t, 'r--', t, t**3.5, 'bo', t, t**3, 'g^')
plt.show()

# %%
x = np.linspace(0, 2, 100)


plt.plot(x, x, label='rus')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='uzb')  # etc.
plt.plot(x, x**3, label='can')
plt.plot(x, x**4, label='usa')
plt.xlabel('aaa')
plt.ylabel('bbb')
plt.title("Another sample")
plt.legend()

# %%
x = [0, 3, 7, 9]
y = [0, 5, 9, 10]
z = [0, 4, 6, 11]
plt.plot(x, y)
plt.plot(x, z)
plt.plot(y, z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is x","this is y", "this is z"])
plt.show()

# %%
import matplotlib.pyplot as plt 
labels = ['First', 'Second', 'Third', 'Last']
values = [7,10,7.9, 6]

bars = plt.bar(labels, values)
patterns = ['o','*','+','/']
for bar in bars:
    bar.set_hatch(patterns.pop())

# bars[0].set_hatch('x')
# bars[1].set_hatch('o')
# bars[2].set_hatch('/')

plt.title('meaningless  bars!')
plt.xlabel('Bar names')
plt.ylabel('Bar heights')

plt.figure(figsize=(4,6))
                  
plt.show()
